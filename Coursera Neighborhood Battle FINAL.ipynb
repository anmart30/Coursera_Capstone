# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Objective

# %% [markdown]
# The main objective is to do a study of the neighborhoods in New York City and recommend where is the best place to open a new chinese Restaurant.

# %% [markdown]
# ## Introduction

# %% [markdown]
# This project will try to provide an approach of which can be the best place to open a new chinese restaurant in the New York City.
#
# Since there are lots of chinese restaurants in New York we weill try to detect which are the area with most of the new york population and where is the best chinese restaurant and try to stablish a correlation with where is the best place to open a new one.
#
# With data science we will try to see which are the borough and neighboroughs of New York and taking advantage of the localization and rating valorates of the restaurant to give a visual interfaz with the actua chinese restaurants.

# %% [markdown]
# ## Data

# %% [markdown]
# The data that we need to study will be:
#
#     - Borough and Neighborhood population
#
#     - Number of chinese restuarant per borough and neighborhood in a specified radius
#
#     - Restaurant quality

# %% [markdown]
# For this, we required the following websites and libraries:
#
#     - New York data:
#     https://cocl.us/new_york_dataset
#
#     - Coordinates of the different locations:
#     https://geocoder.readthedocs.io/index.html
#
#     - Venues and venue categories or near-venues:
#     https://foursquare.com
#
#     - Map displaying with the output information:
#     https://pypi.org/project/folium/

# %% [markdown]
# ### Part 1: Define de New York Dataset

# %% [markdown]
# ##### Importing the required libraries

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import os
import folium # map rendering library

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib as mp
import re
import csv
# %matplotlib inline

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ##### Lets going to create the latitude and longitude coordinates using the FourSquare API and get the top 100 venues with a radius of 1000 m. First with the New York center input as an addres and Geoogle Maps geocoding API.

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    locatidn = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = 'JBSSK1LVMH5GFGMULQUK0CTRI3UBKGNEPXOE5VMKZ315DODH'# Foursquare ID, note there is a daily call quota limit 
    CLIENT_SECRET ='2420XVZ2LHZ3QZSXNJDIA3PPT015RQE4ZLQVGCQEDU1BND1O' # Foursquare Secret, note there is a daily call quota it
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ##### Define a function to get venue details like like count , rating , tip counts for a given venue id. to be used for ranking.

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = 'JBSSK1LVMH5GFGMULQUK0CTRI3UBKGNEPXOE5VMKZ315DODH'# Foursquare ID, note there is a daily call quota limit 
    CLIENT_SECRET ='2420XVZ2LHZ3QZSXNJDIA3PPT015RQE4ZLQVGCQEDU1BND1O' # Foursquare Secret, note there is a daily call quota it it
    VERSION = '20180605' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %%
new_york_data=get_new_york_data()

# %%
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %% [markdown]
# ##### There are a total of 306 different Neighborhoods in New York.

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(9,5), dpi = 80)
plt.title('Number of Neighbourhood in NYC by Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Neighborhood', fontsize=15)
new_york_data.groupby('Borough')['Neighborhood'].count().plot(kind='bar')
plt.legend()
plt.show()

# %% [markdown]
# Queens is the most densely populated borough in New York City with around 80 neighborhoods.

# %% [markdown]
# ## Part 2: Study of the neighborhood list with Chinese Restaurants

# %% [markdown]
# ##### We are going to study the amount of chinese restaurant per each neaighborhood

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name']
chinese_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    chinese_resturants=venues[venues['Category']=='Chinese Restaurant']   
    print('(',count,'/',len(new_york_data),')','Chinese Resturants in '+Neighborhood+', '+Borough+':'+str(len(chinese_resturants)))
    for resturant_detail in chinese_resturants.values.tolist():
        id, name , category=resturant_detail
        chinese_rest_ny = chinese_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Chinese Resturants in Wakefield, Bronx:1
# ( 2 / 306 ) Chinese Resturants in Co-op City, Bronx:1
# ( 3 / 306 ) Chinese Resturants in Eastchester, Bronx:1
# ( 4 / 306 ) Chinese Resturants in Fieldston, Bronx:1
# ( 5 / 306 ) Chinese Resturants in Riverdale, Bronx:0
# ( 6 / 306 ) Chinese Resturants in Kingsbridge, Bronx:0
# ( 7 / 306 ) Chinese Resturants in Marble Hill, Manhattan:1
# ( 8 / 306 ) Chinese Resturants in Woodlawn, Bronx:1
# ( 9 / 306 ) Chinese Resturants in Norwood, Bronx:2
# ( 10 / 306 ) Chinese Resturants in Williamsbridge, Bronx:1
# ( 11 / 306 ) Chinese Resturants in Baychester, Bronx:1
# ( 12 / 306 ) Chinese Resturants in Pelham Parkway, Bronx:4
# ( 13 / 306 ) Chinese Resturants in City Island, Bronx:1
# ( 14 / 306 ) Chinese Resturants in Bedford Park, Bronx:2
# ( 15 / 306 ) Chinese Resturants in University Heights, Bronx:0
# ( 16 / 306 ) Chinese Resturants in Morris Heights, Bronx:1
# ( 17 / 306 ) Chinese Resturants in Fordham, Bronx:1
# ( 18 / 306 ) Chinese Resturants in East Tremont, Bronx:2
# ( 19 / 306 ) Chinese Resturants in West Farms, Bronx:1
# ( 20 / 306 ) Chinese Resturants in High  Bridge, Bronx:0
# ( 21 / 306 ) Chinese Resturants in Melrose, Bronx:2
# ( 22 / 306 ) Chinese Resturants in Mott Haven, Bronx:0
# ( 23 / 306 ) Chinese Resturants in Port Morris, Bronx:0
# ( 24 / 306 ) Chinese Resturants in Longwood, Bronx:1
# ( 25 / 306 ) Chinese Resturants in Hunts Point, Bronx:1
# ( 26 / 306 ) Chinese Resturants in Morrisania, Bronx:0
# ( 27 / 306 ) Chinese Resturants in Soundview, Bronx:2
# ( 28 / 306 ) Chinese Resturants in Clason Point, Bronx:0
# ( 29 / 306 ) Chinese Resturants in Throgs Neck, Bronx:0
# ( 30 / 306 ) Chinese Resturants in Country Club, Bronx:0
# ( 31 / 306 ) Chinese Resturants in Parkchester, Bronx:1
# ( 32 / 306 ) Chinese Resturants in Westchester Square, Bronx:2
# ( 33 / 306 ) Chinese Resturants in Van Nest, Bronx:0
# ( 34 / 306 ) Chinese Resturants in Morris Park, Bronx:1
# ( 35 / 306 ) Chinese Resturants in Belmont, Bronx:0
# ( 36 / 306 ) Chinese Resturants in Spuyten Duyvil, Bronx:1
# ( 37 / 306 ) Chinese Resturants in North Riverdale, Bronx:2
# ( 38 / 306 ) Chinese Resturants in Pelham Bay, Bronx:0
# ( 39 / 306 ) Chinese Resturants in Schuylerville, Bronx:1
# ( 40 / 306 ) Chinese Resturants in Edgewater Park, Bronx:0
# ( 41 / 306 ) Chinese Resturants in Castle Hill, Bronx:0
# ( 42 / 306 ) Chinese Resturants in Olinville, Bronx:2
# ( 43 / 306 ) Chinese Resturants in Pelham Gardens, Bronx:0
# ( 44 / 306 ) Chinese Resturants in Concourse, Bronx:3
# ( 45 / 306 ) Chinese Resturants in Unionport, Bronx:1
# ( 46 / 306 ) Chinese Resturants in Edenwald, Bronx:3
# ( 47 / 306 ) Chinese Resturants in Bay Ridge, Brooklyn:2
# ( 48 / 306 ) Chinese Resturants in Bensonhurst, Brooklyn:4
# ( 49 / 306 ) Chinese Resturants in Sunset Park, Brooklyn:4
# ( 50 / 306 ) Chinese Resturants in Greenpoint, Brooklyn:1
# ( 51 / 306 ) Chinese Resturants in Gravesend, Brooklyn:2
# ( 52 / 306 ) Chinese Resturants in Brighton Beach, Brooklyn:0
# ( 53 / 306 ) Chinese Resturants in Sheepshead Bay, Brooklyn:1
# ( 54 / 306 ) Chinese Resturants in Manhattan Terrace, Brooklyn:0
# ( 55 / 306 ) Chinese Resturants in Flatbush, Brooklyn:1
# ( 56 / 306 ) Chinese Resturants in Crown Heights, Brooklyn:0
# ( 57 / 306 ) Chinese Resturants in East Flatbush, Brooklyn:0
# ( 58 / 306 ) Chinese Resturants in Kensington, Brooklyn:2
# ( 59 / 306 ) Chinese Resturants in Windsor Terrace, Brooklyn:2
# ( 60 / 306 ) Chinese Resturants in Prospect Heights, Brooklyn:0
# ( 61 / 306 ) Chinese Resturants in Brownsville, Brooklyn:0
# ( 62 / 306 ) Chinese Resturants in Williamsburg, Brooklyn:2
# ( 63 / 306 ) Chinese Resturants in Bushwick, Brooklyn:0
# ( 64 / 306 ) Chinese Resturants in Bedford Stuyvesant, Brooklyn:1
# ( 65 / 306 ) Chinese Resturants in Brooklyn Heights, Brooklyn:1
# ( 66 / 306 ) Chinese Resturants in Cobble Hill, Brooklyn:0
# ( 67 / 306 ) Chinese Resturants in Carroll Gardens, Brooklyn:0
# ( 68 / 306 ) Chinese Resturants in Red Hook, Brooklyn:1
# ( 69 / 306 ) Chinese Resturants in Gowanus, Brooklyn:0
# ( 70 / 306 ) Chinese Resturants in Fort Greene, Brooklyn:0
# ( 71 / 306 ) Chinese Resturants in Park Slope, Brooklyn:0
# ( 72 / 306 ) Chinese Resturants in Cypress Hills, Brooklyn:0
# ( 73 / 306 ) Chinese Resturants in East New York, Brooklyn:3
# ( 74 / 306 ) Chinese Resturants in Starrett City, Brooklyn:2
# ( 75 / 306 ) Chinese Resturants in Canarsie, Brooklyn:2
# ( 76 / 306 ) Chinese Resturants in Flatlands, Brooklyn:2
# ( 77 / 306 ) Chinese Resturants in Mill Island, Brooklyn:1
# ( 78 / 306 ) Chinese Resturants in Manhattan Beach, Brooklyn:0
# ( 79 / 306 ) Chinese Resturants in Coney Island, Brooklyn:1
# ( 80 / 306 ) Chinese Resturants in Bath Beach, Brooklyn:6
# ( 81 / 306 ) Chinese Resturants in Borough Park, Brooklyn:1
# ( 82 / 306 ) Chinese Resturants in Dyker Heights, Brooklyn:3
# ( 83 / 306 ) Chinese Resturants in Gerritsen Beach, Brooklyn:0
# ( 84 / 306 ) Chinese Resturants in Marine Park, Brooklyn:2
# ( 85 / 306 ) Chinese Resturants in Clinton Hill, Brooklyn:1
# ( 86 / 306 ) Chinese Resturants in Sea Gate, Brooklyn:1
# ( 87 / 306 ) Chinese Resturants in Downtown, Brooklyn:3
# ( 88 / 306 ) Chinese Resturants in Boerum Hill, Brooklyn:2
# ( 89 / 306 ) Chinese Resturants in Prospect Lefferts Gardens, Brooklyn:1
# ( 90 / 306 ) Chinese Resturants in Ocean Hill, Brooklyn:2
# ( 91 / 306 ) Chinese Resturants in City Line, Brooklyn:2
# ( 92 / 306 ) Chinese Resturants in Bergen Beach, Brooklyn:0
# ( 93 / 306 ) Chinese Resturants in Midwood, Brooklyn:1
# ( 94 / 306 ) Chinese Resturants in Prospect Park South, Brooklyn:2
# ( 95 / 306 ) Chinese Resturants in Georgetown, Brooklyn:4
# ( 96 / 306 ) Chinese Resturants in East Williamsburg, Brooklyn:0
# ( 97 / 306 ) Chinese Resturants in North Side, Brooklyn:1
# ( 98 / 306 ) Chinese Resturants in South Side, Brooklyn:2
# ( 99 / 306 ) Chinese Resturants in Ocean Parkway, Brooklyn:1
# ( 100 / 306 ) Chinese Resturants in Fort Hamilton, Brooklyn:2
# ( 101 / 306 ) Chinese Resturants in Chinatown, Manhattan:4
# ( 102 / 306 ) Chinese Resturants in Washington Heights, Manhattan:2
# ( 103 / 306 ) Chinese Resturants in Inwood, Manhattan:2
# ( 104 / 306 ) Chinese Resturants in Hamilton Heights, Manhattan:2
# ( 105 / 306 ) Chinese Resturants in Manhattanville, Manhattan:2
# ( 106 / 306 ) Chinese Resturants in Central Harlem, Manhattan:2
# ( 107 / 306 ) Chinese Resturants in East Harlem, Manhattan:2
# ( 108 / 306 ) Chinese Resturants in Upper East Side, Manhattan:0
# ( 109 / 306 ) Chinese Resturants in Yorkville, Manhattan:1
# ( 110 / 306 ) Chinese Resturants in Lenox Hill, Manhattan:0
# ( 111 / 306 ) Chinese Resturants in Roosevelt Island, Manhattan:1
# ( 112 / 306 ) Chinese Resturants in Upper West Side, Manhattan:1
# ( 113 / 306 ) Chinese Resturants in Lincoln Square, Manhattan:0
# ( 114 / 306 ) Chinese Resturants in Clinton, Manhattan:0
# ( 115 / 306 ) Chinese Resturants in Midtown, Manhattan:1
# ( 116 / 306 ) Chinese Resturants in Murray Hill, Manhattan:1
# ( 117 / 306 ) Chinese Resturants in Chelsea, Manhattan:1
# ( 118 / 306 ) Chinese Resturants in Greenwich Village, Manhattan:1
# ( 119 / 306 ) Chinese Resturants in East Village, Manhattan:1
# ( 120 / 306 ) Chinese Resturants in Lower East Side, Manhattan:2
# ( 121 / 306 ) Chinese Resturants in Tribeca, Manhattan:0
# ( 122 / 306 ) Chinese Resturants in Little Italy, Manhattan:1
# ( 123 / 306 ) Chinese Resturants in Soho, Manhattan:0
# ( 124 / 306 ) Chinese Resturants in West Village, Manhattan:2
# ( 125 / 306 ) Chinese Resturants in Manhattan Valley, Manhattan:3
# ( 126 / 306 ) Chinese Resturants in Morningside Heights, Manhattan:4
# ( 127 / 306 ) Chinese Resturants in Gramercy, Manhattan:1
# ( 128 / 306 ) Chinese Resturants in Battery Park City, Manhattan:0
# ( 129 / 306 ) Chinese Resturants in Financial District, Manhattan:0
# ( 130 / 306 ) Chinese Resturants in Astoria, Queens:0
# ( 131 / 306 ) Chinese Resturants in Woodside, Queens:2
# ( 132 / 306 ) Chinese Resturants in Jackson Heights, Queens:0
# ( 133 / 306 ) Chinese Resturants in Elmhurst, Queens:4
# ( 134 / 306 ) Chinese Resturants in Howard Beach, Queens:2
# ( 135 / 306 ) Chinese Resturants in Corona, Queens:4
# ( 136 / 306 ) Chinese Resturants in Forest Hills, Queens:2
# ( 137 / 306 ) Chinese Resturants in Kew Gardens, Queens:0
# ( 138 / 306 ) Chinese Resturants in Richmond Hill, Queens:2
# ( 139 / 306 ) Chinese Resturants in Flushing, Queens:13
# ( 140 / 306 ) Chinese Resturants in Long Island City, Queens:1
# ( 141 / 306 ) Chinese Resturants in Sunnyside, Queens:4
# ( 142 / 306 ) Chinese Resturants in East Elmhurst, Queens:1
# ( 143 / 306 ) Chinese Resturants in Maspeth, Queens:4
# ( 144 / 306 ) Chinese Resturants in Ridgewood, Queens:2
# ( 145 / 306 ) Chinese Resturants in Glendale, Queens:1
# ( 146 / 306 ) Chinese Resturants in Rego Park, Queens:4
# ( 147 / 306 ) Chinese Resturants in Woodhaven, Queens:1
# ( 148 / 306 ) Chinese Resturants in Ozone Park, Queens:2
# ( 149 / 306 ) Chinese Resturants in South Ozone Park, Queens:2
# ( 150 / 306 ) Chinese Resturants in College Point, Queens:2
# ( 151 / 306 ) Chinese Resturants in Whitestone, Queens:2
# ( 152 / 306 ) Chinese Resturants in Bayside, Queens:2
# ( 153 / 306 ) Chinese Resturants in Auburndale, Queens:2
# ( 154 / 306 ) Chinese Resturants in Little Neck, Queens:5
# ( 155 / 306 ) Chinese Resturants in Douglaston, Queens:4
# ( 156 / 306 ) Chinese Resturants in Glen Oaks, Queens:1
# ( 157 / 306 ) Chinese Resturants in Bellerose, Queens:1
# ( 158 / 306 ) Chinese Resturants in Kew Gardens Hills, Queens:1
# ( 159 / 306 ) Chinese Resturants in Fresh Meadows, Queens:9
# ( 160 / 306 ) Chinese Resturants in Briarwood, Queens:2
# ( 161 / 306 ) Chinese Resturants in Jamaica Center, Queens:4
# ( 162 / 306 ) Chinese Resturants in Oakland Gardens, Queens:4
# ( 163 / 306 ) Chinese Resturants in Queens Village, Queens:2
# ( 164 / 306 ) Chinese Resturants in Hollis, Queens:0
# ( 165 / 306 ) Chinese Resturants in South Jamaica, Queens:0
# ( 166 / 306 ) Chinese Resturants in St. Albans, Queens:1
# ( 167 / 306 ) Chinese Resturants in Rochdale, Queens:1
# ( 168 / 306 ) Chinese Resturants in Springfield Gardens, Queens:0
# ( 169 / 306 ) Chinese Resturants in Cambria Heights, Queens:1
# ( 170 / 306 ) Chinese Resturants in Rosedale, Queens:0
# ( 171 / 306 ) Chinese Resturants in Far Rockaway, Queens:3
# ( 172 / 306 ) Chinese Resturants in Broad Channel, Queens:1
# ( 173 / 306 ) Chinese Resturants in Breezy Point, Queens:0
# ( 174 / 306 ) Chinese Resturants in Steinway, Queens:1
# ( 175 / 306 ) Chinese Resturants in Beechhurst, Queens:0
# ( 176 / 306 ) Chinese Resturants in Bay Terrace, Queens:1
# ( 177 / 306 ) Chinese Resturants in Edgemere, Queens:0
# ( 178 / 306 ) Chinese Resturants in Arverne, Queens:0
# ( 179 / 306 ) Chinese Resturants in Rockaway Beach, Queens:1
# ( 180 / 306 ) Chinese Resturants in Neponsit, Queens:1
# ( 181 / 306 ) Chinese Resturants in Murray Hill, Queens:0
# ( 182 / 306 ) Chinese Resturants in Floral Park, Queens:2
# ( 183 / 306 ) Chinese Resturants in Holliswood, Queens:4
# ( 184 / 306 ) Chinese Resturants in Jamaica Estates, Queens:3
# ( 185 / 306 ) Chinese Resturants in Queensboro Hill, Queens:7
# ( 186 / 306 ) Chinese Resturants in Hillcrest, Queens:2
# ( 187 / 306 ) Chinese Resturants in Ravenswood, Queens:1
# ( 188 / 306 ) Chinese Resturants in Lindenwood, Queens:3
# ( 189 / 306 ) Chinese Resturants in Laurelton, Queens:2
# ( 190 / 306 ) Chinese Resturants in Lefrak City, Queens:4
# ( 191 / 306 ) Chinese Resturants in Belle Harbor, Queens:0
# ( 192 / 306 ) Chinese Resturants in Rockaway Park, Queens:0
# ( 193 / 306 ) Chinese Resturants in Somerville, Queens:0
# ( 194 / 306 ) Chinese Resturants in Brookville, Queens:0
# ( 195 / 306 ) Chinese Resturants in Bellaire, Queens:2
# ( 196 / 306 ) Chinese Resturants in North Corona, Queens:0
# ( 197 / 306 ) Chinese Resturants in Forest Hills Gardens, Queens:1
# ( 198 / 306 ) Chinese Resturants in St. George, Staten Island:2
# ( 199 / 306 ) Chinese Resturants in New Brighton, Staten Island:0
# ( 200 / 306 ) Chinese Resturants in Stapleton, Staten Island:0
# ( 201 / 306 ) Chinese Resturants in Rosebank, Staten Island:2
# ( 202 / 306 ) Chinese Resturants in West Brighton, Staten Island:1
# ( 203 / 306 ) Chinese Resturants in Grymes Hill, Staten Island:1
# ( 204 / 306 ) Chinese Resturants in Todt Hill, Staten Island:0
# ( 205 / 306 ) Chinese Resturants in South Beach, Staten Island:0
# ( 206 / 306 ) Chinese Resturants in Port Richmond, Staten Island:2
# ( 207 / 306 ) Chinese Resturants in Mariner's Harbor, Staten Island:1
# ( 208 / 306 ) Chinese Resturants in Port Ivory, Staten Island:0
# ( 209 / 306 ) Chinese Resturants in Castleton Corners, Staten Island:2
# ( 210 / 306 ) Chinese Resturants in New Springville, Staten Island:0
# ( 211 / 306 ) Chinese Resturants in Travis, Staten Island:0
# ( 212 / 306 ) Chinese Resturants in New Dorp, Staten Island:2
# ( 213 / 306 ) Chinese Resturants in Oakwood, Staten Island:0
# ( 214 / 306 ) Chinese Resturants in Great Kills, Staten Island:1
# ( 215 / 306 ) Chinese Resturants in Eltingville, Staten Island:1
# ( 216 / 306 ) Chinese Resturants in Annadale, Staten Island:0
# ( 217 / 306 ) Chinese Resturants in Woodrow, Staten Island:0
# ( 218 / 306 ) Chinese Resturants in Tottenville, Staten Island:0
# ( 219 / 306 ) Chinese Resturants in Tompkinsville, Staten Island:0
# ( 220 / 306 ) Chinese Resturants in Silver Lake, Staten Island:0
# ( 221 / 306 ) Chinese Resturants in Sunnyside, Staten Island:0
# ( 222 / 306 ) Chinese Resturants in Ditmas Park, Brooklyn:1
# ( 223 / 306 ) Chinese Resturants in Wingate, Brooklyn:0
# ( 224 / 306 ) Chinese Resturants in Rugby, Brooklyn:3
# ( 225 / 306 ) Chinese Resturants in Park Hill, Staten Island:0
# ( 226 / 306 ) Chinese Resturants in Westerleigh, Staten Island:3
# ( 227 / 306 ) Chinese Resturants in Graniteville, Staten Island:3
# ( 228 / 306 ) Chinese Resturants in Arlington, Staten Island:0
# ( 229 / 306 ) Chinese Resturants in Arrochar, Staten Island:0
# ( 230 / 306 ) Chinese Resturants in Grasmere, Staten Island:0
# ( 231 / 306 ) Chinese Resturants in Old Town, Staten Island:0
# ( 232 / 306 ) Chinese Resturants in Dongan Hills, Staten Island:1
# ( 233 / 306 ) Chinese Resturants in Midland Beach, Staten Island:1
# ( 234 / 306 ) Chinese Resturants in Grant City, Staten Island:1
# ( 235 / 306 ) Chinese Resturants in New Dorp Beach, Staten Island:0
# ( 236 / 306 ) Chinese Resturants in Bay Terrace, Staten Island:1
# ( 237 / 306 ) Chinese Resturants in Huguenot, Staten Island:0
# ( 238 / 306 ) Chinese Resturants in Pleasant Plains, Staten Island:0
# ( 239 / 306 ) Chinese Resturants in Butler Manor, Staten Island:0
# ( 240 / 306 ) Chinese Resturants in Charleston, Staten Island:1
# ( 241 / 306 ) Chinese Resturants in Rossville, Staten Island:0
# ( 242 / 306 ) Chinese Resturants in Arden Heights, Staten Island:1
# ( 243 / 306 ) Chinese Resturants in Greenridge, Staten Island:1
# ( 244 / 306 ) Chinese Resturants in Heartland Village, Staten Island:0
# ( 245 / 306 ) Chinese Resturants in Chelsea, Staten Island:0
# ( 246 / 306 ) Chinese Resturants in Bloomfield, Staten Island:0
# ( 247 / 306 ) Chinese Resturants in Bulls Head, Staten Island:3
# ( 248 / 306 ) Chinese Resturants in Carnegie Hill, Manhattan:0
# ( 249 / 306 ) Chinese Resturants in Noho, Manhattan:1
# ( 250 / 306 ) Chinese Resturants in Civic Center, Manhattan:4
# ( 251 / 306 ) Chinese Resturants in Midtown South, Manhattan:1
# ( 252 / 306 ) Chinese Resturants in Richmond Town, Staten Island:0
# ( 253 / 306 ) Chinese Resturants in Shore Acres, Staten Island:2
# ( 254 / 306 ) Chinese Resturants in Clifton, Staten Island:2
# ( 255 / 306 ) Chinese Resturants in Concord, Staten Island:0
# ( 256 / 306 ) Chinese Resturants in Emerson Hill, Staten Island:0
# ( 257 / 306 ) Chinese Resturants in Randall Manor, Staten Island:1
# ( 258 / 306 ) Chinese Resturants in Howland Hook, Staten Island:0
# ( 259 / 306 ) Chinese Resturants in Elm Park, Staten Island:3
# ( 260 / 306 ) Chinese Resturants in Remsen Village, Brooklyn:3
# ( 261 / 306 ) Chinese Resturants in New Lots, Brooklyn:1
# ( 262 / 306 ) Chinese Resturants in Paerdegat Basin, Brooklyn:0
# ( 263 / 306 ) Chinese Resturants in Mill Basin, Brooklyn:2
# ( 264 / 306 ) Chinese Resturants in Jamaica Hills, Queens:3
# ( 265 / 306 ) Chinese Resturants in Utopia, Queens:4
# ( 266 / 306 ) Chinese Resturants in Pomonok, Queens:1
# ( 267 / 306 ) Chinese Resturants in Astoria Heights, Queens:2
# ( 268 / 306 ) Chinese Resturants in Claremont Village, Bronx:0
# ( 269 / 306 ) Chinese Resturants in Concourse Village, Bronx:2
# ( 270 / 306 ) Chinese Resturants in Mount Eden, Bronx:2
# ( 271 / 306 ) Chinese Resturants in Mount Hope, Bronx:0
# ( 272 / 306 ) Chinese Resturants in Sutton Place, Manhattan:1
# ( 273 / 306 ) Chinese Resturants in Hunters Point, Queens:0
# ( 274 / 306 ) Chinese Resturants in Turtle Bay, Manhattan:0
# ( 275 / 306 ) Chinese Resturants in Tudor City, Manhattan:0
# ( 276 / 306 ) Chinese Resturants in Stuyvesant Town, Manhattan:0
# ( 277 / 306 ) Chinese Resturants in Flatiron, Manhattan:1
# ( 278 / 306 ) Chinese Resturants in Sunnyside Gardens, Queens:1
# ( 279 / 306 ) Chinese Resturants in Blissville, Queens:3
# ( 280 / 306 ) Chinese Resturants in Fulton Ferry, Brooklyn:0
# ( 281 / 306 ) Chinese Resturants in Vinegar Hill, Brooklyn:0
# ( 282 / 306 ) Chinese Resturants in Weeksville, Brooklyn:2
# ( 283 / 306 ) Chinese Resturants in Broadway Junction, Brooklyn:1
# ( 284 / 306 ) Chinese Resturants in Dumbo, Brooklyn:0
# ( 285 / 306 ) Chinese Resturants in Manor Heights, Staten Island:3
# ( 286 / 306 ) Chinese Resturants in Willowbrook, Staten Island:2
# ( 287 / 306 ) Chinese Resturants in Sandy Ground, Staten Island:0
# ( 288 / 306 ) Chinese Resturants in Egbertville, Staten Island:0
# ( 289 / 306 ) Chinese Resturants in Roxbury, Queens:0
# ( 290 / 306 ) Chinese Resturants in Homecrest, Brooklyn:3
# ( 291 / 306 ) Chinese Resturants in Middle Village, Queens:2
# ( 292 / 306 ) Chinese Resturants in Prince's Bay, Staten Island:1
# ( 293 / 306 ) Chinese Resturants in Lighthouse Hill, Staten Island:0
# ( 294 / 306 ) Chinese Resturants in Richmond Valley, Staten Island:0
# ( 295 / 306 ) Chinese Resturants in Malba, Queens:2
# ( 296 / 306 ) Chinese Resturants in Highland Park, Brooklyn:0
# ( 297 / 306 ) Chinese Resturants in Madison, Brooklyn:1
# ( 298 / 306 ) Chinese Resturants in Bronxdale, Bronx:4
# ( 299 / 306 ) Chinese Resturants in Allerton, Bronx:3
# ( 300 / 306 ) Chinese Resturants in Kingsbridge Heights, Bronx:2
# ( 301 / 306 ) Chinese Resturants in Erasmus, Brooklyn:3
# ( 302 / 306 ) Chinese Resturants in Hudson Yards, Manhattan:0
# ( 303 / 306 ) Chinese Resturants in Hammels, Queens:1
# ( 304 / 306 ) Chinese Resturants in Bayswater, Queens:1
# ( 305 / 306 ) Chinese Resturants in Queensbridge, Queens:0
# ( 306 / 306 ) Chinese Resturants in Fox Hills, Staten Island:1

# %%
chinese_rest_ny.shape
# Out:
# (395, 4)

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of Chinese Restaurants in NYC by Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of Chinese Restaurant', fontsize=15)
chinese_rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
plt.legend()
plt.show()

# %% [markdown]
# Queens is the Borough with more Chinese Restaurants.

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(9,5), dpi = 100)
plt.title('Number of Chinese Restaurants in NYC by Neighbourhood')
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('No.of Chinese Restaurants', fontsize=15)

chinese_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
plt.legend()

plt.show()

# %% [markdown]
# And Flushing is the Neighborhood with more number of Chinese Restaurants

# %% [markdown]
# ## Part 3: Prepare neighborhood list with the Chinese Restaurants in it with info about them provided by customers.

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
chinese_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1

for row in chinese_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row

    # prepare neighborhood list that contains chinese resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
chinese_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in chinese_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except (IndexError, KeyError) as e:
        print('No data available for id=',ID)
        id,name,likes,rating,tips=[0]*5
        
    print('(',count,'/',len(chinese_rest_ny),')','processed')
    chinese_rest_stats_ny = chinese_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4edbac4e775bcc53fc0ed5f8
# ( 1 / 395 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4c66dcfaaebea593955a74d0  Chinese Buffet      7     5.2    10
# ( 2 / 395 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4dabc3dc93a04642f09ccabd  Xing Lung Chinese Restaurant      6     6.7     0
# ( 3 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4cc4d337be40a35d390b814c
# ( 4 / 395 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  4d965fd061a3a1cde4989a42  Lucky Star Chinese Restaurant      4     7.8
#
#    Tips
# 0     5
# ( 5 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4c0d7f85b1b676b030b3e086
# ( 6 / 395 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4e4d0387bd413c4cc66dfd72  Hung Hing Chinese Restaurant      5     6.6     2
# ( 7 / 395 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  4e2e08021838f1c552b6b8eb  Choi Yuan - Chinese Restaurant      6     6.3
#
#    Tips
# 0     8
# ( 8 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e4df7a9bd4101d0d79f472f
# ( 9 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e4df7a7bd4101d0d79f46f2
# ( 10 / 395 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4b9d6b45f964a52078ab36e3  Mr. Q's Chinese Restaurant     10     7.7    10
# ( 11 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e4cf8c9bd413c4cc66da6c3
# ( 12 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4c7dbf7f10916dcba78e2a96
# ( 13 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4c9699246b35a1436d4b2fdc
# ( 14 / 395 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  4bfc652bf14fa593c1f5c9d4  City Island Chinese Resturant      6     6.3
#
#    Tips
# 0     4
# ( 15 / 395 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4e4d0387bd413c4cc66dfd72  Hung Hing Chinese Restaurant      5     6.6     2
# ( 16 / 395 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  4e2e08021838f1c552b6b8eb  Choi Yuan - Chinese Restaurant      6     6.3
#
#    Tips
# 0     8
# ( 17 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4ded52a2ae6052cbed0423a8
# ( 18 / 395 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  566f33e7498e44c2501bda81  Panda Express     12     7.5     2
# ( 19 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4ccf58277f56a1434cfec6a6
# ( 20 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4f4348da19834bc91f55b4f0
# ( 21 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4ccf58277f56a1434cfec6a6
# ( 22 / 395 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4ce9aeae678aa093b7a0efea  Merry Land Buffet     12     6.6     3
# ( 23 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 506f4ac1e4b09f6bb9d4241a
# ( 24 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e93a2e0e5faf79bbd76977e
# ( 25 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4b9442b6f964a520b97134e3
# ( 26 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e6d29a0b0fb273d16817e6c
# ( 27 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4ba01296f964a5209f5737e3
# ( 28 / 395 ) processed
#                          ID                             Name  Likes  Rating  \
# 0  4b89b62df964a520ff4c32e3  Sabor Latino Seafood Restaurant      5     7.1
#
#    Tips
# 0     8
# ( 29 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4bc210da4cdfc9b61d799521
# ( 30 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 5682fd34498ec8eb5a66114f
# ( 31 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 5682fd34498ec8eb5a66114f
# ( 32 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4b2283aff964a520204824e3
# ( 33 / 395 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4c28cca7ed0ac9b6b2c160aa  New China      2     6.2     4
# ( 34 / 395 ) processed
#                          ID                               Name  Likes  Rating  \
# 0  4ca4fda4d971b1f77da5f2e0  Golden Phoenix Chinese Restaurant      4     5.7
#
#    Tips
# 0     1
# ( 35 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4cf00d9262ef6dcb5847025a
# ( 36 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4c102bf0ce640f471a8d3952
# ( 37 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4d683ab99968236a39286ea9
# ( 38 / 395 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  4d9a695ee5fd6ea8e3096df5  Lucky House Chinese Restaurant      5     7.0
#
#    Tips
# 0     2
# ( 39 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 506f4ac1e4b09f6bb9d4241a
# ( 40 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4da0c70b7aee5481bda6b2fe
# ( 41 / 395 ) processed
#                          ID                             Name  Likes  Rating  \
# 0  4b89b62df964a520ff4c32e3  Sabor Latino Seafood Restaurant      5     7.1
#
#    Tips
# 0     8
# ( 42 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4edbac4e775bcc53fc0ed5f8
# ( 43 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e4df7abbd4101d0d79f476b
# ( 44 / 395 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4e4df7a9bd4101d0d79f472f
# ( 45 / 395 ) processed
#                          ID Name  Likes  Rating  Tips
# 0  5553702c498ecb85f99d8f37  XIN      6     7.5     4
# ( 46 / 395 ) processed
#                          ID                 Name  Likes  Rating  Tips
# 0  4b1c3b4cf964a520bb0424e3  Grand Sichuan House     37     8.3    24
# ( 47 / 395 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  574a1a53498e6a1b7cb336cb  Orchid Dynasty      6     7.6     1
# ( 48 / 395 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  5b5fa5476dcf04003993a767  Mr. Bun 包大人      6     7.2     0
# ( 49 / 395 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4bdcc1043904a593ba9e4f9e  New Ruans      9     7.0     2
# ( 50 / 395 ) processed
# No data available for id= 54f6521c498eb03ddc080d18
# ( 51 / 395 ) processed
# No data available for id= 51d868ac498ef583276dcf4b
# ( 52 / 395 ) processed
# No data available for id= 4bfaf805d0382d7f520ac90a
# ( 53 / 395 ) processed
# No data available for id= 4d783c6a930ef04dac0fb44f
# ( 54 / 395 ) processed
# No data available for id= 4b6c63e0f964a5201f362ce3
# ( 55 / 395 ) processed
# No data available for id= 54820ad7498e5a6cf6ff64e2
# ( 56 / 395 ) processed
# No data available for id= 4c0037c0369476b0a6118f1f
# ( 57 / 395 ) processed
# No data available for id= 4f550f5de4b07c31b64df0bc
# ( 58 / 395 ) processed
# No data available for id= 5b366e6f0d173f002c48e42c
# ( 59 / 395 ) processed
# No data available for id= 4be756a4910020a1db5ad514
# ( 60 / 395 ) processed
# No data available for id= 4a948ca2f964a520f72120e3
# ( 61 / 395 ) processed
# No data available for id= 4db4863ccda1c57c825d83c8
# ( 62 / 395 ) processed
# No data available for id= 54e39b14498e9c646b42958e
# ( 63 / 395 ) processed
# No data available for id= 4a948ca2f964a520f72120e3
# ( 64 / 395 ) processed
# No data available for id= 54b318a1498eb29e9541053a
# ( 65 / 395 ) processed
# No data available for id= 58df00318cfe546addb99246
# ( 66 / 395 ) processed
# No data available for id= 4bfec075369476b04fcc8c1f
# ( 67 / 395 ) processed
# No data available for id= 5db3649a8d15ba00089b4e9b
# ( 68 / 395 ) processed
# No data available for id= 4cd9eb02847da1cdae76029a
# ( 69 / 395 ) processed
# No data available for id= 4cd4dd3e67adf04d8b102a91
# ( 70 / 395 ) processed
# No data available for id= 4dd9d62dd1647fcf3e85255e
# ( 71 / 395 ) processed
# No data available for id= 4ec699aee30071991400cdf8
# ( 72 / 395 ) processed
# No data available for id= 4d62d5dfe4fe5481b6cd9a9e
# ( 73 / 395 ) processed
# No data available for id= 5510a863498e5b4305870699
# ( 74 / 395 ) processed
# No data available for id= 4f7507a7e4b07eec1fdb7e04
# ( 75 / 395 ) processed
# No data available for id= 4d57409bba5b224bc7a32514
# ( 76 / 395 ) processed
# No data available for id= 4c8d0e7355fba093abe164ab
# ( 77 / 395 ) processed
# No data available for id= 4c71de9b8efc370408c1117d
# ( 78 / 395 ) processed
# No data available for id= 514f8b4be4b01f10c950f1c7
# ( 79 / 395 ) processed
# No data available for id= 4bedc857e24d20a17afc7114
# ( 80 / 395 ) processed
# No data available for id= 5b5fa5476dcf04003993a767
# ( 81 / 395 ) processed
# No data available for id= 4b9301d7f964a5204c2e34e3
# ( 82 / 395 ) processed
# No data available for id= 4bdcc1043904a593ba9e4f9e
# ( 83 / 395 ) processed
# No data available for id= 54ce8283498ea0f009041f78
# ( 84 / 395 ) processed
# No data available for id= 54f6521c498eb03ddc080d18
# ( 85 / 395 ) processed
# No data available for id= 4bb0091bf964a52018333ce3
# ( 86 / 395 ) processed
# No data available for id= 4a4ab3bff964a5201fac1fe3
# ( 87 / 395 ) processed
# No data available for id= 4b1c3b4cf964a520bb0424e3
# ( 88 / 395 ) processed
# No data available for id= 4b512cbaf964a520f64527e3
# ( 89 / 395 ) processed
# No data available for id= 4a5beec3f964a52006bc1fe3
# ( 90 / 395 ) processed
# No data available for id= 4b5a6114f964a52043c128e3
# ( 91 / 395 ) processed
# No data available for id= 4c85489ec5a995212abf9305
# ( 92 / 395 ) processed
# No data available for id= 4a71ff01f964a52016da1fe3
# ( 93 / 395 ) processed
# No data available for id= 4bedc857e24d20a17afc7114
# ( 94 / 395 ) processed
# No data available for id= 59da9590e1f0aa52976b8f35
# ( 95 / 395 ) processed
# No data available for id= 5db3649a8d15ba00089b4e9b
# ( 96 / 395 ) processed
# No data available for id= 585d72449f25836f2b2b7a1b
# ( 97 / 395 ) processed
# No data available for id= 585d72449f25836f2b2b7a1b
# ( 98 / 395 ) processed
# No data available for id= 59da9590e1f0aa52976b8f35
# ( 99 / 395 ) processed
# No data available for id= 4bfafc771134b713e48c0fc9
# ( 100 / 395 ) processed
# No data available for id= 4d8151697c956dcb09cff27b
# ( 101 / 395 ) processed
# No data available for id= 4fdaa2bae4b056d3bc5b453a
# ( 102 / 395 ) processed
# No data available for id= 4cd4dd3e67adf04d8b102a91
# ( 103 / 395 ) processed
# No data available for id= 4f326c1a19836c91c7d64648
# ( 104 / 395 ) processed
# No data available for id= 4cf703a264e3721e72a424c8
# ( 105 / 395 ) processed
# No data available for id= 4bfafc771134b713e48c0fc9
# ( 106 / 395 ) processed
# No data available for id= 4be756a4910020a1db5ad514
# ( 107 / 395 ) processed
# No data available for id= 4ee01ae9f7903c92cd2e0c6a
# ( 108 / 395 ) processed
# No data available for id= 4c8d0e7355fba093abe164ab
# ( 109 / 395 ) processed
# No data available for id= 4ba66e74f964a520c05139e3
# ( 110 / 395 ) processed
# No data available for id= 4e4ce4a1bd413c4cc66d03da
# ( 111 / 395 ) processed
# No data available for id= 58df00318cfe546addb99246
# ( 112 / 395 ) processed
# No data available for id= 58df00318cfe546addb99246
# ( 113 / 395 ) processed
# No data available for id= 54b318a1498eb29e9541053a
# ( 114 / 395 ) processed
# No data available for id= 4e7cdba0e4cd68dacf20e1a3
# ( 115 / 395 ) processed
# No data available for id= 4b512cbaf964a520f64527e3
# ( 116 / 395 ) processed
# No data available for id= 4b1c3b4cf964a520bb0424e3
# ( 117 / 395 ) processed
# No data available for id= 4db3374590a0843f295fb69b
# ( 118 / 395 ) processed
# No data available for id= 5894c9a15e56b417cf79e553
# ( 119 / 395 ) processed
# No data available for id= 5c965dad5455b2002c058659
# ( 120 / 395 ) processed
# No data available for id= 5d754979ea4bf40007c080c4
# ( 121 / 395 ) processed
# No data available for id= 4b292f38f964a520939a24e3
# ( 122 / 395 ) processed
# No data available for id= 4b3fe94af964a520e2b125e3
# ( 123 / 395 ) processed
# No data available for id= 4b9aeeedf964a52086e435e3
# ( 124 / 395 ) processed
# No data available for id= 4bd5f4d229eb9c74c64594e1
# ( 125 / 395 ) processed
# No data available for id= 54e52c00498ed1a732aa2037
# ( 126 / 395 ) processed
# No data available for id= 4cd76fd7dfb4a1cd7195645c
# ( 127 / 395 ) processed
# No data available for id= 5b4a97c16adbf5002ce288c2
# ( 128 / 395 ) processed
# No data available for id= 4bf348fce5eba593c8711e90
# ( 129 / 395 ) processed
# No data available for id= 4bf348fce5eba593c8711e90
# ( 130 / 395 ) processed
# No data available for id= 4bd1f6909854d13a38a2fa4d
# ( 131 / 395 ) processed
# No data available for id= 4ae650f0f964a52063a621e3
# ( 132 / 395 ) processed
# No data available for id= 4d9f6b7fa428a1cdf404c804
# ( 133 / 395 ) processed
# No data available for id= 536e6f06498eaee664b4938e
# ( 134 / 395 ) processed
# No data available for id= 56759406498ecd2d68a85eec
# ( 135 / 395 ) processed
# No data available for id= 5529bfd8498ec6ce692d8015
# ( 136 / 395 ) processed
# No data available for id= 4e3484038877beb5e9a22a0b
# ( 137 / 395 ) processed
# No data available for id= 4e3484038877beb5e9a22a0b
# ( 138 / 395 ) processed
# No data available for id= 44e9b421f964a520a5371fe3
# ( 139 / 395 ) processed
# No data available for id= 5a20df1742d8c2528e74211f
# ( 140 / 395 ) processed
# No data available for id= 5647ee82498e8bfc0ddef53d
# ( 141 / 395 ) processed
# No data available for id= 5b380f649deb7d00399fdf9d
# ( 142 / 395 ) processed
# No data available for id= 4a801643f964a5209ef41fe3
# ( 143 / 395 ) processed
# No data available for id= 5894c9a15e56b417cf79e553
# ( 144 / 395 ) processed
# No data available for id= 526eeb54498e9674b5d9034a
# ( 145 / 395 ) processed
# No data available for id= 4e1df590b61c7cb34d9735a8
# ( 146 / 395 ) processed
# No data available for id= 59ac42570868a23a1e0fde8f
# ( 147 / 395 ) processed
# No data available for id= 5ba99889f05ca8003a126617
# ( 148 / 395 ) processed
# No data available for id= 58fbdc8fe0755067a6dcf3ee
# ( 149 / 395 ) processed
# No data available for id= 5ba99889f05ca8003a126617
# ( 150 / 395 ) processed
# No data available for id= 5b4a97c16adbf5002ce288c2
# ( 151 / 395 ) processed
# No data available for id= 58fbdc8fe0755067a6dcf3ee
# ( 152 / 395 ) processed
# No data available for id= 59ac42570868a23a1e0fde8f
# ( 153 / 395 ) processed
# No data available for id= 5f8f4321094d0d6876179d8c
# ( 154 / 395 ) processed
# No data available for id= 4ae1d8b2f964a520e78721e3
# ( 155 / 395 ) processed
# No data available for id= 5a466fc5610f0447488800e2
# ( 156 / 395 ) processed
# No data available for id= 56296f14498edb1ed77b64a3
# ( 157 / 395 ) processed
# No data available for id= 4eaf0752d3e30d448393b841
# ( 158 / 395 ) processed
# No data available for id= 59cfd6697564f73b6b943326
# ( 159 / 395 ) processed
# No data available for id= 4e4d0d0fbd413c4cc66e402c
# ( 160 / 395 ) processed
# No data available for id= 4ba57b0af964a5205f0b39e3
# ( 161 / 395 ) processed
# No data available for id= 4bc8bd4f92b376b00f16523a
# ( 162 / 395 ) processed
# No data available for id= 4e4d0d2fbd413c4cc66e416c
# ( 163 / 395 ) processed
# No data available for id= 4c320798ed37a59388256b03
# ( 164 / 395 ) processed
# No data available for id= 4e4cdcc0bd413c4cc66cc3a0
# ( 165 / 395 ) processed
# No data available for id= 4e541516d22d7b9b6575ebbc
# ( 166 / 395 ) processed
# No data available for id= 4bafed40f964a520152c3ce3
# ( 167 / 395 ) processed
# No data available for id= 4bfc59bce9d8c928a46ab2c7
# ( 168 / 395 ) processed
# No data available for id= 4c350ac6452620a1502b260f
# ( 169 / 395 ) processed
# No data available for id= 4bd20e32046076b0491f7371
# ( 170 / 395 ) processed
# No data available for id= 5747a89b498ee4b7a5106556
# ( 171 / 395 ) processed
# No data available for id= 52235ea211d2fe55782d764c
# ( 172 / 395 ) processed
# No data available for id= 4ef37491d3e32dc398c7c5c7
# ( 173 / 395 ) processed
# No data available for id= 5990ab0a826444188d18dabc
# ( 174 / 395 ) processed
# No data available for id= 4a1845c8f964a52092791fe3
# ( 175 / 395 ) processed
# No data available for id= 4faff7eae4b03b8055801cde
# ( 176 / 395 ) processed
# No data available for id= 4c78756397028cfaec16d8fe
# ( 177 / 395 ) processed
# No data available for id= 4d1bcddc1356224bc6410abe
# ( 178 / 395 ) processed
# No data available for id= 4ab7b8a3f964a520927a20e3
# ( 179 / 395 ) processed
# No data available for id= 4ac38216f964a520929b20e3
# ( 180 / 395 ) processed
# No data available for id= 4ccf3d177f56a1430d3fc6a6
# ( 181 / 395 ) processed
# No data available for id= 59bb19bebcbf7a6bb69bf937
# ( 182 / 395 ) processed
# No data available for id= 4e026cd7fa76007240170736
# ( 183 / 395 ) processed
# No data available for id= 5c9a607d25fb7b002c724043
# ( 184 / 395 ) processed
# No data available for id= 4bb91c86b35776b0e5a1c901
# ( 185 / 395 ) processed
# No data available for id= 4b4a7016f964a520a18726e3
# ( 186 / 395 ) processed
# No data available for id= 4aece833f964a52024cc21e3
# ( 187 / 395 ) processed
# No data available for id= 4bbd13baa8cf76b0a95fb1fd
# ( 188 / 395 ) processed
# No data available for id= 4b3a7560f964a520d56725e3
# ( 189 / 395 ) processed
# No data available for id= 4d80d69d6bd8b60cdc8b507c
# ( 190 / 395 ) processed
# No data available for id= 4d586ba98147f04db338a254
# ( 191 / 395 ) processed
# No data available for id= 4f6fa232e4b0a235d8a92406
# ( 192 / 395 ) processed
# No data available for id= 4dc80d82d164eb9ca02d1b43
# ( 193 / 395 ) processed
# No data available for id= 4c703259d97fa1434b58f5ca
# ( 194 / 395 ) processed
# No data available for id= 4ba25cdff964a52051f137e3
# ( 195 / 395 ) processed
# No data available for id= 4bd9fe963904a5939194449e
# ( 196 / 395 ) processed
# No data available for id= 56316c73498ebdd0e0e53e95
# ( 197 / 395 ) processed
# No data available for id= 4c8aa1b63dc2a1cd0ca9ae32
# ( 198 / 395 ) processed
# No data available for id= 4bafed40f964a520152c3ce3
# ( 199 / 395 ) processed
# No data available for id= 4edac00e0aaf49e02a0e2f73
# ( 200 / 395 ) processed
# No data available for id= 4e3f1364b0fb875af8786fcd
# ( 201 / 395 ) processed
# No data available for id= 4cedc3a83b03f04dc77236dc
# ( 202 / 395 ) processed
# No data available for id= 4c5de5a285a1e21e32db5a11
# ( 203 / 395 ) processed
# No data available for id= 4e4e3d8bbd4101d0d7a5b330
# ( 204 / 395 ) processed
# No data available for id= 4d3f1f7205b8721e921fa437
# ( 205 / 395 ) processed
# No data available for id= 4d8805b7d85f370481b0c9db
# ( 206 / 395 ) processed
# No data available for id= 4bffe248ca1920a1206ced81
# ( 207 / 395 ) processed
# No data available for id= 4bb674486edc76b0ecf8301c
# ( 208 / 395 ) processed
# No data available for id= 4f628efbe4b03be1015fa338
# ( 209 / 395 ) processed
# No data available for id= 4ce842849f776ea8190b5d22
# ( 210 / 395 ) processed
# No data available for id= 4b78929ff964a520aad72ee3
# ( 211 / 395 ) processed
# No data available for id= 4ce842849f776ea8190b5d22
# ( 212 / 395 ) processed
# No data available for id= 4c1b9e9463750f47c524b567
# ( 213 / 395 ) processed
# No data available for id= 53794fd211d282a3cce576a2
# ( 214 / 395 ) processed
# No data available for id= 53acac39498e3f6a67265048
# ( 215 / 395 ) processed
# No data available for id= 4bc25d5b4cdfc9b627109621
# ( 216 / 395 ) processed
# No data available for id= 571ab7b2498ed52e0d5f4bca
# ( 217 / 395 ) processed
# No data available for id= 49f3a080f964a520c36a1fe3
# ( 218 / 395 ) processed
# No data available for id= 53794fd211d282a3cce576a2
# ( 219 / 395 ) processed
# No data available for id= 4bc25d5b4cdfc9b627109621
# ( 220 / 395 ) processed
# No data available for id= 571ab7b2498ed52e0d5f4bca
# ( 221 / 395 ) processed
# No data available for id= 49f3a080f964a520c36a1fe3
# ( 222 / 395 ) processed
# No data available for id= 4d1677796d103704665730bd
# ( 223 / 395 ) processed
# No data available for id= 4e4dfb2abd4101d0d79f8d98
# ( 224 / 395 ) processed
# No data available for id= 4c5a18e26407d13a1301b428
# ( 225 / 395 ) processed
# No data available for id= 567c9683498ea7d84c364d8c
# ( 226 / 395 ) processed
# No data available for id= 4c682095b80abe9aee4ed1e5
# ( 227 / 395 ) processed
# No data available for id= 4b493b67f964a520e16a26e3
# ( 228 / 395 ) processed
# No data available for id= 4ba022fbf964a520cf5c37e3
# ( 229 / 395 ) processed
# No data available for id= 4c563940b7a31b8d6cb44dda
# ( 230 / 395 ) processed
# No data available for id= 4bc76fe08b7c9c74f97436cf
# ( 231 / 395 ) processed
# No data available for id= 5d10ce03a743550023e9d986
# ( 232 / 395 ) processed
# No data available for id= 4c086416009a0f47eb21e6bf
# ( 233 / 395 ) processed
# No data available for id= 4b61d128f964a520d1242ae3
# ( 234 / 395 ) processed
# No data available for id= 4c5a18e26407d13a1301b428
# ( 235 / 395 ) processed
# No data available for id= 55707f69498e9a716399de69
# ( 236 / 395 ) processed
# No data available for id= 5aef90f3b9b37b002ceb20d4
# ( 237 / 395 ) processed
# No data available for id= 4ce49482e571a09332bc8587
# ( 238 / 395 ) processed
# No data available for id= 4c90ffc5238c6dcbb754bc55
# ( 239 / 395 ) processed
# No data available for id= 57b902d4498ea31e223ebd15
# ( 240 / 395 ) processed
# No data available for id= 5a2b366193bd636532b50bdb
# ( 241 / 395 ) processed
# No data available for id= 4b0ae7a3f964a520c92923e3
# ( 242 / 395 ) processed
# No data available for id= 4bbf563cf353d13aea697e10
# ( 243 / 395 ) processed
# No data available for id= 4e5e5fa6aeb78833bb8b5dc8
# ( 244 / 395 ) processed
# No data available for id= 52951e3d11d22599a056c587
# ( 245 / 395 ) processed
# No data available for id= 4b95a2c2f964a52043ad34e3
# ( 246 / 395 ) processed
# No data available for id= 4c256035b7b8a593c6393ee8
# ( 247 / 395 ) processed
# No data available for id= 4ea312218b81a02f89dcdc67
# ( 248 / 395 ) processed
# No data available for id= 4c6efa6ed7fab1f73b055ac9
# ( 249 / 395 ) processed
# No data available for id= 4e4e41e8bd4101d0d7a620e0
# ( 250 / 395 ) processed
# No data available for id= 4eb9c26046906fa3574d411f
# ( 251 / 395 ) processed
# No data available for id= 4e4e41dcbd4101d0d7a61f7e
# ( 252 / 395 ) processed
# No data available for id= 4de6e9acae60db140a896bd3
# ( 253 / 395 ) processed
# No data available for id= 51d81d9e5019b8b339258089
# ( 254 / 395 ) processed
# No data available for id= 4b2bcee2f964a52061bb24e3
# ( 255 / 395 ) processed
# No data available for id= 4d69549ede28224b0ac241be
# ( 256 / 395 ) processed
# No data available for id= 4c02eb2e39d476b0e9652fa7
# ( 257 / 395 ) processed
# No data available for id= 4cb337c21463a143efe7b2a9
# ( 258 / 395 ) processed
# No data available for id= 4d1677796d103704665730bd
# ( 259 / 395 ) processed
# No data available for id= 4b8601a1f964a5203f7d31e3
# ( 260 / 395 ) processed
# No data available for id= 4e4e3e1fbd4101d0d7a5c27a
# ( 261 / 395 ) processed
# No data available for id= 4c20ec904889a5932f262720
# ( 262 / 395 ) processed
# No data available for id= 4e4dfb24bd4101d0d79f8cf5
# ( 263 / 395 ) processed
# No data available for id= 4ce49482e571a09332bc8587
# ( 264 / 395 ) processed
# No data available for id= 4b54a474f964a5205ac427e3
# ( 265 / 395 ) processed
# No data available for id= 4f32982919836c91c7e70a30
# ( 266 / 395 ) processed
# No data available for id= 4f844c6fe4b0059705cb042c
# ( 267 / 395 ) processed
# No data available for id= 50e9c4b1e4b0541e6c67a2ab
# ( 268 / 395 ) processed
# No data available for id= 559f3c6a498e9eb732ee3027
# ( 269 / 395 ) processed
# No data available for id= 4c56000b3e2220a163eb3ea5
# ( 270 / 395 ) processed
# No data available for id= 4d93dd049892a1cd99799569
# ( 271 / 395 ) processed
# No data available for id= 52019f6b498edfb499f84202
# ( 272 / 395 ) processed
# No data available for id= 517d47f1e4b04f1b6e2f03f3
# ( 273 / 395 ) processed
# No data available for id= 4bd8e0dae914a5930afa54fa
# ( 274 / 395 ) processed
# No data available for id= 4f89f3bce4b04a075f23de7d
# ( 275 / 395 ) processed
# No data available for id= 4ae78dbff964a52056ac21e3
# ( 276 / 395 ) processed
# No data available for id= 4bca326b511f95210b4bafc7
# ( 277 / 395 ) processed
# No data available for id= 4b9e559af964a520c4da36e3
# ( 278 / 395 ) processed
# No data available for id= 4b661f63f964a520e6142be3
# ( 279 / 395 ) processed
# No data available for id= 4d85271f61676dcbf7b883e4
# ( 280 / 395 ) processed
# No data available for id= 4e4e3ddcbd4101d0d7a5bb16
# ( 281 / 395 ) processed
# No data available for id= 56316c73498ebdd0e0e53e95
# ( 282 / 395 ) processed
# No data available for id= 4c8aa1b63dc2a1cd0ca9ae32
# ( 283 / 395 ) processed
# No data available for id= 4edac00e0aaf49e02a0e2f73
# ( 284 / 395 ) processed
# No data available for id= 4c320798ed37a59388256b03
# ( 285 / 395 ) processed
# No data available for id= 4c59c1d3d3aee21ea2066955
# ( 286 / 395 ) processed
# No data available for id= 4d8528cf81fdb1f75a2e0cc0
# ( 287 / 395 ) processed
# No data available for id= 4bfc59bce9d8c928a46ab2c7
# ( 288 / 395 ) processed
# No data available for id= 4bb6b6952ea19521e52bac2f
# ( 289 / 395 ) processed
# No data available for id= 4de84e54ae60293318ee3daa
# ( 290 / 395 ) processed
# No data available for id= 4d0ea12626fba09377f5fd72
# ( 291 / 395 ) processed
# No data available for id= 4bd36553caff95212bd4d4f0
# ( 292 / 395 ) processed
# No data available for id= 4cf310ca7e0da1cd731e9b97
# ( 293 / 395 ) processed
# No data available for id= 4f32043a19833175d60a05a4
# ( 294 / 395 ) processed
# No data available for id= 4c254b83a852c92818ade46c
# ( 295 / 395 ) processed
# No data available for id= 4c93b85cf244b1f7c6621b1d
# ( 296 / 395 ) processed
# No data available for id= 4c5a155e04f9be9a8f14f160
# ( 297 / 395 ) processed
# No data available for id= 4c53660372cf0f4768a0c4d2
# ( 298 / 395 ) processed
# No data available for id= 4be75c8f2468c928fc720243
# ( 299 / 395 ) processed
# No data available for id= 4c14210c7f7f2d7fae69e068
# ( 300 / 395 ) processed
# No data available for id= 4cb510469c7ba35db1088806
# ( 301 / 395 ) processed
# No data available for id= 4b747adcf964a52010df2de3
# ( 302 / 395 ) processed
# No data available for id= 4c292b6eed0ac9b68a6561aa
# ( 303 / 395 ) processed
# No data available for id= 4be756a4910020a1db5ad514
# ( 304 / 395 ) processed
# No data available for id= 4c1ad571eac020a10a0144c2
# ( 305 / 395 ) processed
# No data available for id= 4d3b0c6d1fc36dcbbc206df5
# ( 306 / 395 ) processed
# No data available for id= 4dbb7ebd5da3ff58ec340169
# ( 307 / 395 ) processed
# No data available for id= 4c254b83a852c92818ade46c
# ( 308 / 395 ) processed
# No data available for id= 4c93b85cf244b1f7c6621b1d
# ( 309 / 395 ) processed
# No data available for id= 4bd6244d7b1876b098188c86
# ( 310 / 395 ) processed
# No data available for id= 5165e9fee4b08d4837e87f35
# ( 311 / 395 ) processed
# No data available for id= 4c5a155e04f9be9a8f14f160
# ( 312 / 395 ) processed
# No data available for id= 4b69eeedf964a520debc2be3
# ( 313 / 395 ) processed
# No data available for id= 4bba73677421a593ebd4c340
# ( 314 / 395 ) processed
# No data available for id= 4cc61c46b2beb1f74faa264c
# ( 315 / 395 ) processed
# No data available for id= 4c14210c7f7f2d7fae69e068
# ( 316 / 395 ) processed
# No data available for id= 4b747adcf964a52010df2de3
# ( 317 / 395 ) processed
# No data available for id= 4bddca41ffdec928876ee6a1
# ( 318 / 395 ) processed
# No data available for id= 4bb23577715eef3be6e984bb
# ( 319 / 395 ) processed
# No data available for id= 4c924bf52626a1cdf368396b
# ( 320 / 395 ) processed
# No data available for id= 5165e9fee4b08d4837e87f35
# ( 321 / 395 ) processed
# No data available for id= 4b6b7476f964a520dd092ce3
# ( 322 / 395 ) processed
# No data available for id= 4d62d78b149637046d7d0395
# ( 323 / 395 ) processed
# No data available for id= 5647ee82498e8bfc0ddef53d
# ( 324 / 395 ) processed
# No data available for id= 5d754979ea4bf40007c080c4
# ( 325 / 395 ) processed
# No data available for id= 5bf4559c65cdf8002c6be196
# ( 326 / 395 ) processed
# No data available for id= 49d3deadf964a5201d5c1fe3
# ( 327 / 395 ) processed
# No data available for id= 5894c9a15e56b417cf79e553
# ( 328 / 395 ) processed
# No data available for id= 4e3484038877beb5e9a22a0b
# ( 329 / 395 ) processed
# No data available for id= 4bd36553caff95212bd4d4f0
# ( 330 / 395 ) processed
# No data available for id= 4d0ea12626fba09377f5fd72
# ( 331 / 395 ) processed
# No data available for id= 4d0ea12626fba09377f5fd72
# ( 332 / 395 ) processed
# No data available for id= 4f32043a19833175d60a05a4
# ( 333 / 395 ) processed
# No data available for id= 4d80eb27208a5481a3a87d67
# ( 334 / 395 ) processed
# No data available for id= 4c254b83a852c92818ade46c
# ( 335 / 395 ) processed
# No data available for id= 4bd6244d7b1876b098188c86
# ( 336 / 395 ) processed
# No data available for id= 4c93b85cf244b1f7c6621b1d
# ( 337 / 395 ) processed
# No data available for id= 4bd4b3bd29eb9c74f13092e1
# ( 338 / 395 ) processed
# No data available for id= 4e63d2867d8b85408a4328cc
# ( 339 / 395 ) processed
# No data available for id= 4d0bdeaeadf0a143dd32857c
# ( 340 / 395 ) processed
# No data available for id= 4c818737d8086dcb1c0f6e52
# ( 341 / 395 ) processed
# No data available for id= 4ee01ae9f7903c92cd2e0c6a
# ( 342 / 395 ) processed
# No data available for id= 4ba66e74f964a520c05139e3
# ( 343 / 395 ) processed
# No data available for id= 4ce49482e571a09332bc8587
# ( 344 / 395 ) processed
# No data available for id= 5aef90f3b9b37b002ceb20d4
# ( 345 / 395 ) processed
# No data available for id= 4e4ce23ebd413c4cc66cf0d8
# ( 346 / 395 ) processed
# No data available for id= 567c9683498ea7d84c364d8c
# ( 347 / 395 ) processed
# No data available for id= 4c563940b7a31b8d6cb44dda
# ( 348 / 395 ) processed
# No data available for id= 5d10ce03a743550023e9d986
# ( 349 / 395 ) processed
# No data available for id= 4c086416009a0f47eb21e6bf
# ( 350 / 395 ) processed
# No data available for id= 4bad4b36f964a520f6423be3
# ( 351 / 395 ) processed
# No data available for id= 51d81d9e5019b8b339258089
# ( 352 / 395 ) processed
# No data available for id= 4c892761bbec6dcbdedbd958
# ( 353 / 395 ) processed
# No data available for id= 4ce9aeae678aa093b7a0efea
# ( 354 / 395 ) processed
# No data available for id= 506f4ac1e4b09f6bb9d4241a
# ( 355 / 395 ) processed
# No data available for id= 4ded52a2ae6052cbed0423a8
# ( 356 / 395 ) processed
# No data available for id= 4da0c70b7aee5481bda6b2fe
# ( 357 / 395 ) processed
# No data available for id= 5cfab769b399f7002c7ef4f6
# ( 358 / 395 ) processed
# No data available for id= 5f8f4321094d0d6876179d8c
# ( 359 / 395 ) processed
# No data available for id= 4bb91c86b35776b0e5a1c901
# ( 360 / 395 ) processed
# No data available for id= 4b4a7016f964a520a18726e3
# ( 361 / 395 ) processed
# No data available for id= 4aece833f964a52024cc21e3
# ( 362 / 395 ) processed
# No data available for id= 4bbd13baa8cf76b0a95fb1fd
# ( 363 / 395 ) processed
# No data available for id= 4daa263f0cb6a89c62682125
# ( 364 / 395 ) processed
# No data available for id= 4c9c2ba40e9bb1f706add15f
# ( 365 / 395 ) processed
# No data available for id= 4d8151697c956dcb09cff27b
# ( 366 / 395 ) processed
# No data available for id= 4be75c8f2468c928fc720243
# ( 367 / 395 ) processed
# No data available for id= 4c53660372cf0f4768a0c4d2
# ( 368 / 395 ) processed
# No data available for id= 4bff2b03daf9c9b6dce8f9ef
# ( 369 / 395 ) processed
# No data available for id= 4be75c8f2468c928fc720243
# ( 370 / 395 ) processed
# No data available for id= 4bff2b03daf9c9b6dce8f9ef
# ( 371 / 395 ) processed
# No data available for id= 4d28b924ebacb1f72efbf34f
# ( 372 / 395 ) processed
# No data available for id= 4b46743ff964a520892126e3
# ( 373 / 395 ) processed
# No data available for id= 4d10177c6331a0931dce5494
# ( 374 / 395 ) processed
# No data available for id= 4bfb224fd2b720a1a5a9326a
# ( 375 / 395 ) processed
# No data available for id= 4c92cc0c1221b1f7c0f014e2
# ( 376 / 395 ) processed
# No data available for id= 4bb7d282b35776b0b83dc801
# ( 377 / 395 ) processed
# No data available for id= 4bffe248ca1920a1206ced81
# ( 378 / 395 ) processed
# No data available for id= 4bb674486edc76b0ecf8301c
# ( 379 / 395 ) processed
# No data available for id= 4be32bd7b02ec9b61fc34ec0
# ( 380 / 395 ) processed
# No data available for id= 4c3f7f2eda3dc928b8f6c5b9
# ( 381 / 395 ) processed
# No data available for id= 4b9d6b45f964a52078ab36e3
# ( 382 / 395 ) processed
# No data available for id= 5085d52ae4b0bdebccdaa1ee
# ( 383 / 395 ) processed
# No data available for id= 4b86ac6ff964a520759531e3
# ( 384 / 395 ) processed
# No data available for id= 4c9699246b35a1436d4b2fdc
# ( 385 / 395 ) processed
# No data available for id= 4c102bf0ce640f471a8d3952
# ( 386 / 395 ) processed
# No data available for id= 4c0d75d37189c928500bd7b6
# ( 387 / 395 ) processed
# No data available for id= 4d965fd061a3a1cde4989a42
# ( 388 / 395 ) processed
# No data available for id= 566f33e7498e44c2501bda81
# ( 389 / 395 ) processed
# No data available for id= 4be756a4910020a1db5ad514
# ( 390 / 395 ) processed
# No data available for id= 4c61d3ec4b5176b0d79dfb16
# ( 391 / 395 ) processed
# No data available for id= 4cfb1dce2d80a143d6a749d8
# ( 392 / 395 ) processed
# No data available for id= 4c72ad2bad69b60cb31b84b9
# ( 393 / 395 ) processed
# No data available for id= 4e4e41e8bd4101d0d7a620e0
# ( 394 / 395 ) processed
# No data available for id= 4cf9aa7ad8468cfadaa9e86b
# ( 395 / 395 ) processed

# %%
chinese_rest_stats_ny.shape
# Out:
# (395, 7)

# %%
chinese_rest_ny.shape
# Out:
# (395, 4)

# %%
chinese_rest_stats_ny.to_csv('chinese_rest_stats_ny.csv', index=False)

# %%
chinese_rest_stats_ny_csv=pd.read_csv('chinese_rest_stats_ny.csv')

# %%
chinese_rest_stats_ny_csv.shape
# Out:
# (395, 7)

# %%
chinese_rest_stats_ny_csv.head()
# Out:
#      Borough Neighborhood                        ID  \
# 0      Bronx    Wakefield                         0
# 1      Bronx   Co-op City  4c66dcfaaebea593955a74d0
# 2      Bronx  Eastchester  4dabc3dc93a04642f09ccabd
# 3      Bronx    Fieldston                         0
# 4  Manhattan  Marble Hill  4d965fd061a3a1cde4989a42
#
#                             Name  Likes  Rating  Tips
# 0                              0      0     0.0     0
# 1                 Chinese Buffet      7     5.2    10
# 2   Xing Lung Chinese Restaurant      6     6.7     0
# 3                              0      0     0.0     0
# 4  Lucky Star Chinese Restaurant      4     7.8     5

# %%
chinese_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       395 non-null    object
#  1   Neighborhood  395 non-null    object
#  2   ID            395 non-null    object
#  3   Name          395 non-null    object
#  4   Likes         395 non-null    object
#  5   Rating        395 non-null    object
#  6   Tips          395 non-null    object
# dtypes: object(7)
# memory usage: 10.9+ KB

# %%
chinese_rest_stats_ny['Likes']=chinese_rest_stats_ny['Likes'].astype('float64')

# %%
chinese_rest_stats_ny['Tips']=chinese_rest_stats_ny['Tips'].astype('float64')

# %%
chinese_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       395 non-null    object
#  1   Neighborhood  395 non-null    object
#  2   ID            395 non-null    object
#  3   Name          395 non-null    object
#  4   Likes         395 non-null    float64
#  5   Rating        395 non-null    object
#  6   Tips          395 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 13.9+ KB

# %%
chinese_rest_stats_ny.iloc[chinese_rest_stats_ny['Likes'].idxmax()]  # ----- Chinese Restaurant with maximum likes
# Out:
# Borough                         Brooklyn
# Neighborhood                   Bay Ridge
# ID              4b1c3b4cf964a520bb0424e3
# Name                 Grand Sichuan House
# Likes                                 37
# Rating                               8.3
# Tips                                  24
# Name: 46, dtype: object

# %%
chinese_rest_stats_ny.iloc[chinese_rest_stats_ny_csv['Rating'].idxmax()]  # ----- Chinese Restaurant with maximum Rating
# Out:
# Borough                         Brooklyn
# Neighborhood                   Bay Ridge
# ID              4b1c3b4cf964a520bb0424e3
# Name                 Grand Sichuan House
# Likes                                 37
# Rating                               8.3
# Tips                                  24
# Name: 46, dtype: object

# %%
chinese_rest_stats_ny.iloc[chinese_rest_stats_ny['Tips'].idxmax()] # ----- Chinese Restaurant with maximum Rating
# Out:
# Borough                         Brooklyn
# Neighborhood                   Bay Ridge
# ID              4b1c3b4cf964a520bb0424e3
# Name                 Grand Sichuan House
# Likes                                 37
# Rating                               8.3
# Tips                                  24
# Name: 46, dtype: object

# %%
ny_neighborhood_stats=chinese_rest_stats_ny_csv.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#         Neighborhood  Average Rating
# 5          Bay Ridge            7.90
# 110      Marble Hill            7.80
# 65           Fordham            7.50
# 139      Parkchester            7.10
# 176        Unionport            7.10
# 52       Eastchester            6.70
# 133          Norwood            6.45
# 10      Bedford Park            6.45
# 31       City Island            6.30
# 131  North Riverdale            5.95

# %%
ny_borough_stats=chinese_rest_stats_ny_csv.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']

# %%
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#          Borough  Average Rating
# 0          Bronx        1.735088
# 1       Brooklyn        0.408696
# 2      Manhattan        0.169565
# 3         Queens        0.000000
# 4  Staten Island        0.000000

# %%
plt.figure(figsize=(9,5), dpi = 100)
plt.title('Average rating of Chinese Restaurant in each  NYC Borough')
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('Average Rating', fontsize=15)
chinese_rest_stats_ny_csv.groupby('Borough').mean()['Rating'].plot(kind='bar')
plt.legend()
plt.show()

# %% [markdown]
# Bronx borough is the one with higher rating for Chinese restaurant, but not data info from the rest of the neighborhoods should be consider.

# %%
ny_neighborhood_stats=chinese_rest_stats_ny_csv[chinese_rest_stats_ny_csv['Rating']>=7.0]

# %%
ny_neighborhood_stats
# Out:
#       Borough    Neighborhood                        ID  \
# 4   Manhattan     Marble Hill  4d965fd061a3a1cde4989a42
# 10      Bronx  Pelham Parkway  4b9d6b45f964a52078ab36e3
# 18      Bronx         Fordham  566f33e7498e44c2501bda81
# 28      Bronx     Parkchester  4b89b62df964a520ff4c32e3
# 38      Bronx       Concourse  4d9a695ee5fd6ea8e3096df5
# 41      Bronx       Unionport  4b89b62df964a520ff4c32e3
# 45   Brooklyn       Bay Ridge  5553702c498ecb85f99d8f37
# 46   Brooklyn       Bay Ridge  4b1c3b4cf964a520bb0424e3
# 47   Brooklyn     Bensonhurst  574a1a53498e6a1b7cb336cb
# 48   Brooklyn     Bensonhurst  5b5fa5476dcf04003993a767
# 49   Brooklyn     Bensonhurst  4bdcc1043904a593ba9e4f9e
#
#                                Name  Likes  Rating  Tips
# 4     Lucky Star Chinese Restaurant      4     7.8     5
# 10       Mr. Q's Chinese Restaurant     10     7.7    10
# 18                    Panda Express     12     7.5     2
# 28  Sabor Latino Seafood Restaurant      5     7.1     8
# 38   Lucky House Chinese Restaurant      5     7.0     2
# 41  Sabor Latino Seafood Restaurant      5     7.1     8
# 45                              XIN      6     7.5     4
# 46              Grand Sichuan House     37     8.3    24
# 47                   Orchid Dynasty      6     7.6     1
# 48                      Mr. Bun 包大人      6     7.2     0
# 49                        New Ruans      9     7.0     2

# %%
new_york_data.head(5)
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats, new_york_data, on='Neighborhood')
ny_neighborhood_stats
# Out:
#     Borough_x    Neighborhood                        ID  \
# 0   Manhattan     Marble Hill  4d965fd061a3a1cde4989a42
# 1       Bronx  Pelham Parkway  4b9d6b45f964a52078ab36e3
# 2       Bronx         Fordham  566f33e7498e44c2501bda81
# 3       Bronx     Parkchester  4b89b62df964a520ff4c32e3
# 4       Bronx       Concourse  4d9a695ee5fd6ea8e3096df5
# 5       Bronx       Unionport  4b89b62df964a520ff4c32e3
# 6    Brooklyn       Bay Ridge  5553702c498ecb85f99d8f37
# 7    Brooklyn       Bay Ridge  4b1c3b4cf964a520bb0424e3
# 8    Brooklyn     Bensonhurst  574a1a53498e6a1b7cb336cb
# 9    Brooklyn     Bensonhurst  5b5fa5476dcf04003993a767
# 10   Brooklyn     Bensonhurst  4bdcc1043904a593ba9e4f9e
#
#                                Name  Likes  Rating  Tips  Borough_y  \
# 0     Lucky Star Chinese Restaurant      4     7.8     5  Manhattan
# 1        Mr. Q's Chinese Restaurant     10     7.7    10      Bronx
# 2                     Panda Express     12     7.5     2      Bronx
# 3   Sabor Latino Seafood Restaurant      5     7.1     8      Bronx
# 4    Lucky House Chinese Restaurant      5     7.0     2      Bronx
# 5   Sabor Latino Seafood Restaurant      5     7.1     8      Bronx
# 6                               XIN      6     7.5     4   Brooklyn
# 7               Grand Sichuan House     37     8.3    24   Brooklyn
# 8                    Orchid Dynasty      6     7.6     1   Brooklyn
# 9                       Mr. Bun 包大人      6     7.2     0   Brooklyn
# 10                        New Ruans      9     7.0     2   Brooklyn
#
#      Latitude  Longitude
# 0   40.876551 -73.910660
# 1   40.857413 -73.854756
# 2   40.860997 -73.896427
# 3   40.837938 -73.856003
# 4   40.834284 -73.915589
# 5   40.829774 -73.850535
# 6   40.625801 -74.030621
# 7   40.625801 -74.030621
# 8   40.611009 -73.995180
# 9   40.611009 -73.995180
# 10  40.611009 -73.995180

# %%
ny_neighborhood_stats.rename(columns={'Borough_x':'Borough'}, inplace=True)
ny_neighborhood_stats
# Out:
#       Borough    Neighborhood                        ID  \
# 0   Manhattan     Marble Hill  4d965fd061a3a1cde4989a42
# 1       Bronx  Pelham Parkway  4b9d6b45f964a52078ab36e3
# 2       Bronx         Fordham  566f33e7498e44c2501bda81
# 3       Bronx     Parkchester  4b89b62df964a520ff4c32e3
# 4       Bronx       Concourse  4d9a695ee5fd6ea8e3096df5
# 5       Bronx       Unionport  4b89b62df964a520ff4c32e3
# 6    Brooklyn       Bay Ridge  5553702c498ecb85f99d8f37
# 7    Brooklyn       Bay Ridge  4b1c3b4cf964a520bb0424e3
# 8    Brooklyn     Bensonhurst  574a1a53498e6a1b7cb336cb
# 9    Brooklyn     Bensonhurst  5b5fa5476dcf04003993a767
# 10   Brooklyn     Bensonhurst  4bdcc1043904a593ba9e4f9e
#
#                                Name  Likes  Rating  Tips  Borough_y  \
# 0     Lucky Star Chinese Restaurant      4     7.8     5  Manhattan
# 1        Mr. Q's Chinese Restaurant     10     7.7    10      Bronx
# 2                     Panda Express     12     7.5     2      Bronx
# 3   Sabor Latino Seafood Restaurant      5     7.1     8      Bronx
# 4    Lucky House Chinese Restaurant      5     7.0     2      Bronx
# 5   Sabor Latino Seafood Restaurant      5     7.1     8      Bronx
# 6                               XIN      6     7.5     4   Brooklyn
# 7               Grand Sichuan House     37     8.3    24   Brooklyn
# 8                    Orchid Dynasty      6     7.6     1   Brooklyn
# 9                       Mr. Bun 包大人      6     7.2     0   Brooklyn
# 10                        New Ruans      9     7.0     2   Brooklyn
#
#      Latitude  Longitude
# 0   40.876551 -73.910660
# 1   40.857413 -73.854756
# 2   40.860997 -73.896427
# 3   40.837938 -73.856003
# 4   40.834284 -73.915589
# 5   40.829774 -73.850535
# 6   40.625801 -74.030621
# 7   40.625801 -74.030621
# 8   40.611009 -73.995180
# 9   40.611009 -73.995180
# 10  40.611009 -73.995180

# %%
ny_neighborhood_stats.sort_values(['Rating'],ascending=False).head()
# Out:
#      Borough    Neighborhood                        ID  \
# 7   Brooklyn       Bay Ridge  4b1c3b4cf964a520bb0424e3
# 0  Manhattan     Marble Hill  4d965fd061a3a1cde4989a42
# 1      Bronx  Pelham Parkway  4b9d6b45f964a52078ab36e3
# 8   Brooklyn     Bensonhurst  574a1a53498e6a1b7cb336cb
# 2      Bronx         Fordham  566f33e7498e44c2501bda81
#
#                             Name  Likes  Rating  Tips  Borough_y   Latitude  \
# 7            Grand Sichuan House     37     8.3    24   Brooklyn  40.625801
# 0  Lucky Star Chinese Restaurant      4     7.8     5  Manhattan  40.876551
# 1     Mr. Q's Chinese Restaurant     10     7.7    10      Bronx  40.857413
# 8                 Orchid Dynasty      6     7.6     1   Brooklyn  40.611009
# 2                  Panda Express     12     7.5     2      Bronx  40.860997
#
#    Longitude
# 7 -74.030621
# 0 -73.910660
# 1 -73.854756
# 8 -73.995180
# 2 -73.896427

# %%
# create map and display it
ny_map = folium.Map(location=(40.693943, -73.985880), zoom_start=12)

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Rating'].map(str)+')'

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2105723b3ddc45de86a37719a444aa63%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2105723b3ddc45de86a37719a444aa63%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2105723b3ddc45de86a37719a444aa63%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2105723b3ddc45de86a37719a444aa63%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.693943%2C%20-73.98588%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Part 4: Conclusions

# %% [markdown]
# - There are a lot of Chinese restaurant in New York city that are not valued so, it's difficut to stablish an accurate study of where is the best place to open a new Chinese restaurant, but with the available info, we can stablsih that the best ranking Chinese restaurant are in The Brox, being the maximum rating restaurant in Manhattan. Nevertheless, is not possible to make an study of other borough due to the lack of information.

# %% [markdown]
# ##### Recommendations:

# %% [markdown]
#     - Its found that the most populated borough is Queens which also contains more of the chinese restaurants in New York. But these restaurants are not valorated.
#     - The people seems to be more willing to valorate the chinese food in Bronx so they probable appreciate a new chinese restuarant.
#     - The best chinese restaurant is in the north of Manhattan, it could be a good place to start a new restaurant due to the close to the Bronx and with a new developing area.
